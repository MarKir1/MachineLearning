# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_data(data, labels, true_betas, train_betas=None):
    print("True Betas: ", true_betas)
    plt.figure(figsize=(5, 8))
    plt.scatter(data[0][labels==1], data[1][labels==1], label="1")
    plt.scatter(data[0][labels==-1], data[1][labels==-1], label="-1")
    plt.plot([0, 10], [0, - true_betas[0] * 10.0 / true_betas[1]], color='red', label="Decision Boundary")
    plt.plot([0, true_betas[0]], [0, true_betas[1]], '--', color='red', label="True Betas")
    if train_betas is not None:
        plt.plot([0, 10], [0, - train_betas[0] * 10.0 / train_betas[1]], color='green', label="Found Boundary")
        plt.plot([0, train_betas[0]], [0, train_betas[1]], '--', color='green', label="Found Betas")
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.ylim(-7,10)
    plt.legend(borderaxespad=0., loc=2, bbox_to_anchor=(1.05, 1))
    plt.show()

# %%
def sigmoid(x, b):
    """
    :param x: 1D-array, features vector for one sample
    :param b: 1D-array, betas of the model
    :return: sigmoid (logistic) of (x,b)
    """
    return 1/(1 + np.exp(-(np.dot(b.T,x))))

# %%
def grad(x, y, b):
    """
    Gradient of log-loss for one sample
    :param y: label of the sample (1 or -1)
    :param x: 1D-array, features vector for the sample
    :param b: 1D-array, betas of the model
    """
    
    m = x.shape[0]

    a = sigmoid(x, b)

    cost = -1/m * np.sum(y * np.log(a) + (1-y) * (np.log(1-a)))

    dz= (1/m) * (a - y)
    db = np.dot(x, dz.T)

    cost = np.squeeze(cost)
    grads = {"db": db}

    return grads, cost

# %%
def optimize(x, y, b, num_iterations, learning_rate, print_cost = False):

    costs = []

    for i in range(num_iterations):
        m = x.shape[0]
        grads, cost = grad(x, y, b)
        b = b - learning_rate * grads["db"]
        if i % 100 == 0:
            costs.append(cost)
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))

    params = {"b": b}
    return params, grads, costs

# %%
def predict(x, b):
    m = x.shape[0]
    y_prediction = np.zeros((1,m))
    w = w.reshape(x.shape[0], 1)
    a = sigmoid(x, b)

    for i in range(a.shape[1]):
        x_exp = np.exp(a)
        x_sum = np.sum(x_exp,axis=1,keepdims=True)
        s = np.divide(x_exp,x_sum)

    y_prediction = 1. * (a > 0.5)

    return y_prediction

# %%
def train(X, Y, num_iterations = 2000, learning_rate = 0.1, print_cost = False):
    """
    Get optimal betas
    :param Y: 1D-array, labels of all data like [1,1,-1,1,-1,-1,1,...]
    :param X: 2D-array of shape (features number, samples number), i.e. vector of all feature vectors
    :param lr: learning rate (eta)
    :return: 1D-array of size of features number, betas
    """
    
    b = np.zeros(X.shape[0])

    parameters, grads, costs = optimize(X, Y, b, num_iterations, learning_rate, print_cost = False)

    b = parameters["b"]

    Y_prediction = predict(X, b)
    d = {"costs": costs,
         "Y_prediction": Y_prediction,
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}

    return d

# %% [markdown]
# #### Execute the next cell to see your result

# %%
import numpy as np
# Generate data
true_betas = np.random.randint(4, 7, 2)  # random betas
true_betas[1] *= -1  # to bring line in positive quarter

data = np.random.uniform(0, 10, 1000).reshape(2, 500)

# %%
data.shape
# Out:
# (2, 500)

# %%
data.T
# Out:
# array([[4.36027230e+00, 4.14915873e+00],
#        [9.55419426e+00, 8.50699546e+00],
#        [7.81127829e+00, 9.33638710e+00],
#        [3.31666456e+00, 4.09315577e+00],
#        [2.51245352e+00, 7.79654970e+00],
#        [2.24564201e+00, 8.38011780e+00],
#        [6.21997232e+00, 8.02788136e+00],
#        [3.99655394e-01, 8.43292991e+00],
#        [2.91664752e+00, 3.31778487e+00],
#        [2.94556485e+00, 8.26863087e+00],
#        [2.07009740e+00, 3.59347702e+00],
#        [4.83588621e+00, 3.47096496e+00],
#        [6.30436916e+00, 9.10198211e+00],
#        [2.75520038e+00, 9.99040764e+00],
#        [9.41818182e+00, 3.21080315e+00],
#        [9.70603343e+00, 6.39891994e+00],
#        [9.90708204e+00, 7.68291179e+00],
#        [5.06969794e+00, 5.96378754e+00],
#        [6.39575940e+00, 3.57888870e+00],
#        [6.80767001e+00, 1.97797641e+00],
#        [4.02810896e+00, 8.72798728e+00],
#        [1.47948417e+00, 3.84478969e+00],
#        [4.32925022e+00, 8.66293502e-01],
#        [7.38077156e-01, 9.51994909e+00],
#        [3.87552179e-01, 9.97750960e+00],
#        [3.85046891e-01, 3.94815189e+00],
#        [4.48080979e+00, 8.49445960e+00],
#        [8.15174302e+00, 6.59157645e+00],
#        [9.84266477e+00, 4.01237610e+00],
#        [7.73455254e+00, 2.19076000e+00],
#        [1.61151700e+00, 8.35473184e+00],
#        [2.50675328e+00, 4.00618151e+00],
#        [1.41593754e+00, 2.72351842e+00],
#        [4.12509306e+00, 7.99824784e+00],
#        [4.43930746e+00, 7.63691838e+00],
#        [3.10000891e+00, 7.66859584e+00],
#        [7.58126922e-01, 1.63728878e+00],
#        [2.65888525e+00, 5.56436664e+00],
#        [4.18648546e+00, 3.93423575e+00],
#        [5.26157205e+00, 4.74032022e+00],
#        [7.62590369e+00, 7.91304957e+00],
#        [1.83204161e+00, 2.31242507e+00],
#        [8.50768236e+00, 2.49926276e+00],
#        [7.00703271e+00, 4.59582982e+00],
#        [8.03058269e+00, 9.75351330e+00],
#        [9.88214573e+00, 5.98970723e+00],
#        [9.54950520e+00, 8.57636564e+00],
#        [7.99282995e+00, 5.86145807e+00],
#        [8.74808941e+00, 6.67841918e+00],
#        [5.47597299e+00, 3.77626370e+00],
#        [1.45732754e-02, 8.57345382e+00],
#        [8.12063496e+00, 7.92602031e+00],
#        [9.93966459e+00, 8.30322338e+00],
#        [3.21198254e+00, 6.28531443e+00],
#        [7.92721837e+00, 5.57287679e+00],
#        [9.64807655e+00, 8.37956203e+00],
#        [4.30035340e-01, 6.74006602e+00],
#        [5.49810077e+00, 4.16033316e+00],
#        [9.50988978e+00, 2.84101093e+00],
#        [3.77958170e+00, 3.33230653e+00],
#        [4.50166582e+00, 4.72860945e-01],
#        [1.83225770e+00, 9.77436131e+00],
#        [9.53856471e+00, 4.38055874e+00],
#        [2.12374374e+00, 3.60359099e+00],
#        [4.99679585e+00, 2.67305387e+00],
#        [5.70202177e+00, 1.15377350e+00],
#        [5.76780080e+00, 1.84030796e+00],
#        [5.47081471e+00, 6.43076060e+00],
#        [5.76073360e+00, 3.33106306e+00],
#        [8.50708886e+00, 1.52764986e+00],
#        [8.75636483e+00, 2.09608517e+00],
#        [3.03153884e-01, 8.63269815e-01],
#        [3.08877178e+00, 7.96303204e+00],
#        [2.73505130e+00, 7.09237355e+00],
#        [7.11528183e+00, 2.36333336e+00],
#        [1.39151756e+00, 7.24903313e+00],
#        [2.62053557e+00, 1.44720283e+00],
#        [5.48754095e+00, 9.07632943e+00],
#        [3.44194187e+00, 2.43925947e+00],
#        [4.79545756e+00, 5.61947323e+00],
#        [4.33284750e+00, 5.31048492e+00],
#        [3.84719183e-01, 3.08947315e+00],
#        [3.49865975e+00, 1.26673809e+00],
#        [5.95746061e+00, 4.41583353e+00],
#        [7.06169387e-01, 2.83140553e+00],
#        [1.45514298e+00, 9.86160781e+00],
#        [7.06524304e+00, 6.84072549e+00],
#        [1.16613852e+00, 7.66954417e+00],
#        [2.84225071e+00, 8.96023562e+00],
#        [3.27511535e+00, 5.44557313e+00],
#        [1.84537170e+00, 2.79050280e+00],
#        [1.96580568e+00, 7.69539954e+00],
#        [4.65272262e+00, 4.76875836e+00],
#        [8.76510023e+00, 5.82970963e+00],
#        [6.62059844e+00, 9.59082622e+00],
#        [9.48490963e+00, 5.15962329e+00],
#        [7.94711280e+00, 1.02813567e+00],
#        [6.16628652e+00, 8.54279528e+00],
#        [5.53547078e+00, 9.12187013e+00],
#        [8.53191665e+00, 9.00865339e+00],
#        [7.20155861e+00, 3.64431164e+00],
#        [3.03932727e+00, 6.16996277e+00],
#        [3.16415380e+00, 6.15436552e+00],
#        [8.98854406e+00, 4.47305737e+00],
#        [6.95129645e-02, 7.49530077e+00],
#        [8.96302438e-01, 2.53854320e-01],
#        [9.26281851e+00, 3.33554893e+00],
#        [3.35833561e+00, 6.53582573e+00],
#        [5.83920876e+00, 1.69531881e+00],
#        [2.14179886e+00, 7.46727729e+00],
#        [5.81208390e+00, 5.85003513e+00],
#        [3.44292961e+00, 9.59369269e+00],
#        [8.98476290e+00, 3.51330104e+00],
#        [4.14752338e+00, 3.86723719e+00],
#        [5.57148676e+00, 2.10862997e+00],
#        [5.46244546e+00, 4.37051558e+00],
#        [5.62025723e+00, 7.01758277e+00],
#        [6.57576012e+00, 3.81961074e-01],
#        [1.97284662e+00, 1.34174614e-01],
#        [1.89277338e+00, 2.89624423e+00],
#        [1.08980731e+00, 5.04324105e+00],
#        [9.36700163e+00, 9.41127099e-01],
#        [2.41457469e+00, 7.24062348e+00],
#        [6.48360263e+00, 9.84086586e+00],
#        [5.77817769e+00, 5.85376971e+00],
#        [1.26430989e+00, 1.48258260e+00],
#        [7.76004548e+00, 2.90521256e+00],
#        [7.93373262e+00, 5.81645127e+00],
#        [3.24042756e+00, 4.42711852e+00],
#        [8.38237146e+00, 1.49390992e+00],
#        [5.46828327e+00, 9.81938765e+00],
#        [5.08564361e+00, 4.05395523e-03],
#        [6.84134876e+00, 3.95138678e+00],
#        [2.69545980e+00, 5.62225333e+00],
#        [3.41781148e+00, 9.91446159e+00],
#        [9.80809196e+00, 5.52204028e+00],
#        [7.79936924e+00, 3.42636751e+00],
#        [4.25328522e+00, 9.64853348e+00],
#        [8.95305298e+00, 4.76982138e+00],
#        [1.73494332e-01, 9.81369511e+00],
#        [9.43954255e+00, 3.32587793e+00],
#        [7.49165849e+00, 2.95210325e+00],
#        [8.66879679e+00, 9.29823404e-01],
#        [5.94688693e+00, 3.30437251e+00],
#        [8.63691816e+00, 4.32276517e+00],
#        [9.95695361e+00, 4.20777257e+00],
#        [7.78733115e+00, 1.39416812e+00],
#        [3.26092344e+00, 2.07353718e-01],
#        [8.38819321e+00, 1.84857062e+00],
#        [1.70139160e+00, 3.55652671e+00],
#        [9.16739712e-01, 7.74372717e+00],
#        [1.13167338e+00, 3.36980273e+00],
#        [6.53832176e+00, 7.47291740e+00],
#        [3.31324269e+00, 8.71035806e+00],
#        [5.89028259e+00, 7.81377571e+00],
#        [1.61016498e+00, 9.19756970e+00],
#        [6.77714767e+00, 8.14459692e+00],
#        [2.32473622e+00, 9.73699812e+00],
#        [4.63843479e+00, 5.91667792e+00],
#        [4.25458840e+00, 5.47329606e-01],
#        [1.03761325e+00, 8.47969820e+00],
#        [4.76609800e+00, 4.88629624e+00],
#        [4.47606983e+00, 4.88647536e+00],
#        [1.63171186e+00, 2.83364515e-01],
#        [5.95151409e+00, 4.68277779e+00],
#        [6.95519130e+00, 9.23931864e+00],
#        [7.21745018e-01, 8.72004926e+00],
#        [6.30897314e+00, 6.79205504e+00],
#        [2.37967338e+00, 2.63473014e+00],
#        [9.68354190e+00, 7.28915988e+00],
#        [7.46531432e+00, 3.66964850e+00],
#        [6.68619615e+00, 7.14430388e+00],
#        [1.95508306e+00, 4.82706708e+00],
#        [4.63711998e-01, 3.47715748e-01],
#        [1.11400678e+00, 7.13515333e+00],
#        [8.13542488e+00, 2.62654619e+00],
#        [2.09428333e+00, 5.01276708e+00],
#        [1.62905426e-01, 7.31707735e-01],
#        [5.04758038e+00, 6.48743250e+00],
#        [4.74814402e+00, 4.20820137e+00],
#        [4.08032408e-01, 9.84143387e+00],
#        [5.66488145e+00, 8.50294891e+00],
#        [6.05430438e+00, 8.22208063e+00],
#        [1.81835632e+00, 4.60788901e+00],
#        [5.57491758e+00, 4.26456705e+00],
#        [9.90560191e+00, 8.03554144e+00],
#        [2.20731977e+00, 2.36661309e+00],
#        [1.28025984e+00, 1.84465153e-01],
#        [5.03735041e+00, 9.59666597e+00],
#        [8.83701638e+00, 3.25178088e+00],
#        [5.20131656e+00, 4.26873078e+00],
#        [2.43977325e+00, 7.43366986e+00],
#        [3.92935918e+00, 6.82980357e+00],
#        [6.81039145e-01, 3.64651930e+00],
#        [9.51752845e+00, 3.39208185e+00],
#        [8.17094303e-02, 7.61765721e+00],
#        [8.64535733e+00, 1.76411897e-01],
#        [5.27224282e+00, 7.80085293e+00],
#        [5.60919407e+00, 7.14265311e-01],
#        [1.06405530e+00, 4.55708199e-01],
#        [1.81315515e+00, 4.82549280e+00],
#        [8.93992506e-01, 3.39523111e+00],
#        [8.42038858e+00, 7.44545527e+00],
#        [9.14023615e+00, 9.96415890e+00],
#        [8.12721890e+00, 6.81288937e+00],
#        [3.69068475e+00, 6.81266895e+00],
#        [4.86700727e+00, 2.74655955e+00],
#        [3.54898352e+00, 9.90028932e+00],
#        [4.45879744e+00, 2.70327056e+00],
#        [6.45299041e+00, 5.22074562e+00],
#        [9.31649328e+00, 1.29931915e+00],
#        [6.72540035e+00, 9.84352442e+00],
#        [8.51712065e+00, 1.43826213e+00],
#        [2.27648631e+00, 5.51230029e-01],
#        [4.20955937e+00, 5.93282774e+00],
#        [8.65086106e-01, 2.50737699e+00],
#        [5.21469524e+00, 3.91624068e+00],
#        [6.26358708e+00, 5.31896901e+00],
#        [4.60052956e-01, 6.18359167e+00],
#        [2.25306007e+00, 3.14417988e+00],
#        [3.21172196e+00, 5.48025520e+00],
#        [9.37523083e+00, 2.98232219e+00],
#        [7.92094234e+00, 8.89349432e+00],
#        [2.48567746e+00, 7.61635558e+00],
#        [7.34915066e+00, 8.16110356e+00],
#        [2.51003222e-01, 4.17420248e+00],
#        [2.23819842e+00, 2.20908618e+00],
#        [9.21609786e+00, 5.25570081e+00],
#        [2.57386689e+00, 2.89877036e+00],
#        [2.88262904e+00, 6.23205235e+00],
#        [6.76425610e+00, 2.91305478e+00],
#        [6.09900789e+00, 4.78133951e+00],
#        [2.96120382e+00, 3.38957513e+00],
#        [8.47467877e-01, 2.10070206e+00],
#        [7.55362179e+00, 7.31767955e+00],
#        [5.43132087e+00, 2.82005520e+00],
#        [2.55931069e+00, 1.76493451e+00],
#        [6.12265828e+00, 4.81138866e+00],
#        [5.81327098e+00, 4.38134842e+00],
#        [4.32892919e+00, 6.05566536e+00],
#        [8.96015518e+00, 3.00644588e+00],
#        [8.51280876e+00, 9.82656337e+00],
#        [8.70742398e-01, 1.68982081e+00],
#        [5.01607394e+00, 5.08341623e+00],
#        [7.26320445e+00, 4.52794695e+00],
#        [8.00382831e+00, 2.69340678e+00],
#        [2.46842105e+00, 2.01992177e+00],
#        [1.74940235e+00, 2.15930468e+00],
#        [6.32037233e+00, 3.71674066e+00],
#        [3.32768753e+00, 7.60468185e+00],
#        [7.77158302e-01, 4.38025813e+00],
#        [3.23082881e+00, 3.67733713e-01],
#        [4.86557798e+00, 4.65077118e+00],
#        [1.23152640e+00, 9.69854630e+00],
#        [5.60947892e+00, 9.13844893e+00],
#        [9.72334855e+00, 3.92335995e+00],
#        [5.40695433e+00, 3.81465619e+00],
#        [6.88436048e+00, 8.90135834e+00],
#        [1.82335737e+00, 3.87529247e+00],
#        [4.07288484e+00, 5.33796938e+00],
#        [9.98129428e+00, 8.25051390e+00],
#        [2.16076682e+00, 2.45827106e+00],
#        [6.12171832e+00, 6.01121689e+00],
#        [8.58150264e+00, 6.23007834e+00],
#        [2.27034475e+00, 8.45145631e+00],
#        [9.80749849e+00, 5.60959915e+00],
#        [6.67019625e+00, 5.05333460e+00],
#        [3.81773306e+00, 4.91685471e+00],
#        [6.80366788e+00, 8.14619064e+00],
#        [2.97899168e+00, 2.25234143e+00],
#        [3.98235471e+00, 4.43341521e-01],
#        [3.85099108e+00, 2.28717404e+00],
#        [7.85742732e+00, 6.74581461e+00],
#        [7.04541650e+00, 6.37510410e+00],
#        [6.41447869e+00, 1.46564937e+00],
#        [5.66265859e-01, 7.51087515e+00],
#        [2.35882427e+00, 6.27132463e+00],
#        [9.05080007e+00, 8.00645827e+00],
#        [3.14476589e+00, 1.65002111e+00],
#        [6.45857260e+00, 2.30555316e-01],
#        [5.91307207e+00, 1.80132100e-01],
#        [9.63617721e+00, 1.05354290e+00],
#        [2.11935186e-01, 5.36214564e+00],
#        [8.87692235e+00, 4.50624107e+00],
#        [6.70940917e+00, 3.33562506e+00],
#        [7.25020057e+00, 9.55072529e+00],
#        [1.71001048e+00, 6.25283327e+00],
#        [7.07237607e+00, 7.92468489e+00],
#        [4.18909369e+00, 2.91329304e+00],
#        [9.40506688e+00, 1.73234061e+00],
#        [7.79599468e+00, 1.11476878e+00],
#        [8.56032980e+00, 1.37579848e+00],
#        [5.14871799e+00, 9.75752005e+00],
#        [3.17783326e+00, 6.67433281e+00],
#        [5.08025330e+00, 8.09648389e+00],
#        [9.70845702e+00, 6.76271343e+00],
#        [9.81914778e+00, 6.52050238e+00],
#        [2.47281940e+00, 9.30626169e+00],
#        [2.69794977e+00, 8.74360704e+00],
#        [5.34354374e+00, 9.89780487e+00],
#        [3.59827571e+00, 3.00939523e-01],
#        [2.76011428e+00, 3.29450154e-01],
#        [8.87395520e-02, 7.54028189e-01],
#        [2.17695517e+00, 1.07306098e+00],
#        [5.93825082e+00, 6.98053882e+00],
#        [8.74567519e+00, 5.18080107e+00],
#        [8.06437300e-01, 8.31893901e+00],
#        [2.87367161e+00, 6.92308304e+00],
#        [4.15825521e+00, 5.41618827e+00]])

# %%
labels = np.array([np.random.choice([1, -1], p=[sigmoid(x, true_betas/3), 1 - sigmoid(x, true_betas/3)]) for x in data.T])

# %% [markdown]
# #### DON'T execute the next cell
# You need example output, to see what kind of figure you should obtain

# %%
plot_data(data, labels, true_betas, train(labels, data.T))
